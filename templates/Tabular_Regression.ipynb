# %% [markdown]
# # Problem Statement

# %% [markdown]
# # Data Imports

# %%
# Helper Function

# !python -m wget https://raw.githubusercontent.com/train-your-model/helper_functions/master/Tabular_Regression/Regression.py

# %%
from Regression import CreateDF

c_df = CreateDF().run()

# %% [markdown]
# **Observations:**
